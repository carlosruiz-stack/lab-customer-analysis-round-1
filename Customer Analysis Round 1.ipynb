# %%
import pandas as pd
import numpy as py

# %%
dataframe1 = pd.read_csv("file1.csv")
dataframe1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                        NaN       0                  1000
# 1                 697953.59%       0                    94
# 2                1288743.17%   48767                   108
# 3                 764586.18%       0                   106
# ...

# %%
dataframe2 = pd.read_csv("file2.csv")
dataframe2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
dataframe3 = pd.read_csv("file3.csv")
dataframe3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df1= dataframe1.head(n=5)
df1
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#    Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0       0                  1000                    1/0/00   Personal Auto
# 1       0                    94                    1/0/00   Personal Auto
# 2   48767                   108                    1/0/00   Personal Auto
# 3       0                   106                    1/0/00  Corporate Auto
# 4   36357                    68                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
df2= dataframe2.head(n=5)
df2
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
df3= dataframe3.head(n=5)
df3
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
shape1 = dataframe1.shape
print(shape1)
# Out:
# (1071, 11)

# %%
shape2 = dataframe2.shape
print(shape2)
# Out:
# (996, 11)

# %%
shape3 = dataframe3.shape
print(shape3)
# Out:
# (7070, 11)

# %%
list(dataframe1.columns)
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount']

# %%
new_df1 = dataframe1.rename(columns={"ST":"State","GENDER":"Gender"})

# %%
list(new_df1.columns)
# Out:
# ['Customer',
#  'State',
#  'Gender',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount']

# %%
list(dataframe1.columns)
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount']

# %%
list(dataframe2.columns)
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Total Claim Amount',
#  'Policy Type',
#  'Vehicle Class']

# %%
new_df2 = dataframe2.rename(columns={"GENDER":"Gender"})

# %%
list(dataframe2.columns)
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Total Claim Amount',
#  'Policy Type',
#  'Vehicle Class']

# %%
list(dataframe3.columns)
# Out:
# ['Customer',
#  'State',
#  'Customer Lifetime Value',
#  'Education',
#  'Gender',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Total Claim Amount',
#  'Vehicle Class']

# %%
concatenaded_dataframe = pd.concat([new_df1,new_df2,dataframe3])
print(concatenaded_dataframe)
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                        NaN       0                  1000
# 1                 697953.59%       0                    94
# 2                1288743.17%   48767                   108
# 3                 764586.18%       0                   106
# ...

# %%
num = concatenaded_dataframe.select_dtypes(include='number')
print(num)
# Out:
#       Income  Monthly Premium Auto  Total Claim Amount
# 0          0                  1000            2.704934
# 1          0                    94         1131.464935
# 2      48767                   108          566.472247
# 3          0                   106          529.881344
# 4      36357                    68           17.269323
# ...      ...                   ...                 ...
# 7065   71941                    73          198.234764
# 7066   21604                    79          379.200000
# 7067       0                    85          790.784983
# 7068   21941                    96          691.200000
# 7069       0                    77          369.600000
#
# [9137 rows x 3 columns]

# %%
cat = concatenaded_dataframe.select_dtypes(exclude='number')
print(cat)
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value Number of Open Complaints     Policy Type  \
# 0                        NaN                    1/0/00   Personal Auto
# 1                 697953.59%                    1/0/00   Personal Auto
# 2                1288743.17%                    1/0/00   Personal Auto
# ...

# %%
new_concatenated_df = concatenaded_dataframe.drop(columns=["Education","Number of Open Complaints"])
print(new_concatenated_df)
# Out:
#      Customer       State Gender Customer Lifetime Value  Income  \
# 0     RB50392  Washington    NaN                     NaN       0
# 1     QZ44356     Arizona      F              697953.59%       0
# 2     AI49188      Nevada      F             1288743.17%   48767
# 3     WW63253  California      M              764586.18%       0
# 4     GA49547  Washington      M              536307.65%   36357
# ...       ...         ...    ...                     ...     ...
# 7065  LA72316  California      M             23405.98798   71941
# 7066  PK87824  California      F             3096.511217   21604
# 7067  TD14365  California      M             8163.890428       0
# 7068  UP19263  California      M             7524.442436   21941
# 7069  Y167826  California      M             2611.836866       0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                     1000   Personal Auto  Four-Door Car            2.704934
# ...

# %%
new_concatenated_df.drop_duplicates()
# Out:
#      Customer       State Gender Customer Lifetime Value  Income  \
# 0     RB50392  Washington    NaN                     NaN       0
# 1     QZ44356     Arizona      F              697953.59%       0
# 2     AI49188      Nevada      F             1288743.17%   48767
# 3     WW63253  California      M              764586.18%       0
# 4     GA49547  Washington      M              536307.65%   36357
# ...       ...         ...    ...                     ...     ...
# 7065  LA72316  California      M             23405.98798   71941
# 7066  PK87824  California      F             3096.511217   21604
# 7067  TD14365  California      M             8163.890428       0
# 7068  UP19263  California      M             7524.442436   21941
# 7069  Y167826  California      M             2611.836866       0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                     1000   Personal Auto  Four-Door Car            2.704934
# ...

# %%
filtered_df= new_concatenated_df[(new_concatenated_df['Income']>0)]
print(filtered_df)
# Out:
#      Customer       State Gender Customer Lifetime Value  Income  \
# 2     AI49188      Nevada      F             1288743.17%   48767
# 4     GA49547  Washington      M              536307.65%   36357
# 5     OC83172      Oregon      F              825629.78%   62902
# 6     XZ87318      Oregon      F              538089.86%   55350
# 8     DY87989      Oregon      M             2412750.40%   14072
# ...       ...         ...    ...                     ...     ...
# 7063  TF56202  California      M             5032.165498   66367
# 7064  YM19146  California      F             4100.398533   47761
# 7065  LA72316  California      M             23405.98798   71941
# 7066  PK87824  California      F             3096.511217   21604
# 7068  UP19263  California      M             7524.442436   21941
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 2                      108   Personal Auto   Two-Door Car          566.472247
# ...
